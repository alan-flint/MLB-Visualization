# %%
import pandas as pd
import numpy as np

# %%
b = pd.read_csv('./core/batting.csv')

# %%
b.columns
# Out:
# Index(['playerID', 'yearID', 'stint', 'teamID', 'lgID', 'G', 'AB', 'R', 'H',
#        '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 'BB', 'SO', 'IBB', 'HBP', 'SH',
#        'SF', 'GIDP'],
#       dtype='object')

# %%
b.groupby('playerID').agg('sum')['HR'].sort_values(ascending = False)[:10]
# Out:
# playerID
# bondsba01    762
# aaronha01    755
# ruthba01     714
# rodrial01    696
# mayswi01     660
# pujolal01    633
# griffke02    630
# thomeji01    612
# sosasa01     609
# robinfr02    586
# Name: HR, dtype: int64

# %%
b.loc[b.playerID == 'troutmi01']
# Out:
#          playerID  yearID  stint teamID lgID    G   AB    R    H  2B  ...  \
# 95485   troutmi01    2011      1    LAA   AL   40  123   20   27   6  ...
# 96905   troutmi01    2012      1    LAA   AL  139  559  129  182  27  ...
# 98309   troutmi01    2013      1    LAA   AL  157  589  109  190  39  ...
# 99745   troutmi01    2014      1    LAA   AL  157  602  115  173  39  ...
# 101227  troutmi01    2015      1    LAA   AL  159  575  104  172  32  ...
# 102713  troutmi01    2016      1    LAA   AL  159  549  123  173  32  ...
# 104196  troutmi01    2017      1    LAA   AL  114  402   92  123  25  ...
# 105723  troutmi01    2018      1    LAA   AL  140  471  101  147  24  ...
#
#           RBI    SB   CS   BB     SO   IBB   HBP   SH    SF  GIDP
# 95485    16.0   4.0  0.0    9   30.0   0.0   2.0  0.0   1.0   2.0
# 96905    83.0  49.0  5.0   67  139.0   4.0   6.0  0.0   7.0   7.0
# 98309    97.0  33.0  7.0  110  136.0  10.0   9.0  0.0   8.0   8.0
# ...

# %%
p = pd.read_csv('./core/Pitching.csv')

# %%
p.head()
# Out:
#     playerID  yearID  stint teamID lgID   W   L   G  GS  CG  ...  IBB  WP  \
# 0  bechtge01    1871      1    PH1  NaN   1   2   3   3   2  ...  NaN   7
# 1  brainas01    1871      1    WS3  NaN  12  15  30  30  30  ...  NaN   7
# 2  fergubo01    1871      1    NY2  NaN   0   0   1   0   0  ...  NaN   2
# 3  fishech01    1871      1    RC1  NaN   4  16  24  24  22  ...  NaN  20
# 4  fleetfr01    1871      1    NY2  NaN   0   1   1   1   1  ...  NaN   0
#
#    HBP  BK     BFP  GF    R  SH  SF  GIDP
# 0  NaN   0   146.0   0   42 NaN NaN   NaN
# 1  NaN   0  1291.0   0  292 NaN NaN   NaN
# 2  NaN   0    14.0   0    9 NaN NaN   NaN
# 3  NaN   0  1080.0   1  257 NaN NaN   NaN
# 4  NaN   0    57.0   0   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
# %load_ext rpy2.ipython
# %R library(ggplot2)
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython
# array(['ggplot2', 'tools', 'stats', 'graphics', 'grDevices', 'utils',
#        'datasets', 'methods', 'base'], dtype='<U9')

# %%
hr = b.groupby('yearID').agg({'HR':'sum'}).reset_index()
hr
# Out:
#      yearID    HR
# 0      1871    47
# 1      1872    37
# 2      1873    47
# 3      1874    40
# 4      1875    40
# 5      1876    40
# 6      1877    24
# 7      1878    23
# 8      1879    58
# 9      1880    62
# 10     1881    76
# 11     1882   178
# 12     1883   238
# 13     1884   689
# 14     1885   323
# 15     1886   413
# 16     1887   606
# 17     1888   521
# 18     1889   667
# 19     1890   764
# 20     1891   585
# 21     1892   417
# 22     1893   460
# 23     1894   629
# 24     1895   488
# 25     1896   404
# 26     1897   368
# 27     1898   299
# 28     1899   352
# 29     1900   254
# ..      ...   ...
# 118    1989  3083
# 119    1990  3317
# 120    1991  3383
# 121    1992  3038
# 122    1993  4030
# 123    1994  3306
# 124    1995  4081
# 125    1996  4962
# 126    1997  4640
# 127    1998  5064
# 128    1999  5528
# 129    2000  5693
# 130    2001  5458
# 131    2002  5059
# 132    2003  5207
# 133    2004  5451
# 134    2005  5017
# 135    2006  5386
# ...

# %%
# %R -i hr

# %%
# %%R
#
# ggplot(aes(x=yearID, y=HR), data = hr) + geom_line()
